# %%
print("Olá Mundo")
# Out:
# Running cells with '.venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/mathe/OneDrive/Documentos/Alura/Estatítica com Python/Curso_Estatística_com_Python_Alura/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
